# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.io as sio

# %%
# I got 32 PRN from this link

# %%
test = sio.loadmat("randomData/codes_L1CA.mat")

# %%
codes = np.array(test['codes_L1CA'])

# %%
corrArr = np.zeros(1023)
for i in range(0,len(corrArr)):
    corrArr[i]= np.correlate(codes[:,8],np.roll(codes[:,8],-i),'valid')/1023
# Out:
# C:\Users\lyric\AppData\Local\Temp\ipykernel_20152\1555105093.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   corrArr[i]= np.correlate(codes[:,8],np.roll(codes[:,8],-i),'valid')/1023

# %%
corrArr.stdd

# %%
# Q1
# np.correlation(codes[:,8],codes[:,8],0,200)
np.correlate(codes[:,8],np.roll(codes[:,8],-200),'valid')
# Out:
# array([-1], dtype=int16)

# %%
# def correlation(PRN1,PRN2,tau1=0,tau2=0):
#     tau1 = tau1%1023
#     tau2 = tau2%1023
#     PRN1 = np.array(PRN1)
#     PRN2 = np.array(PRN2)
#     PRN1 = (np.array([PRN1,PRN1])).flat[tau1:1023+tau1]
#     PRN2 = (np.concatenate([PRN2,PRN2])).flat[tau2:1023+tau2]
#     return np.dot(PRN1,PRN2)

# %%
# idk smthng irnss https://www.researchgate.net/profile/Shylashree-Nn/publication/333893998_F11290476S419/links/5d0b4940299bf1f539d18e01/F11290476S419.pdf

# %%
# Q2
# correlation(codes[:,8],codes[:,16],0,900)
np.correlate(codes[:,8],np.roll(codes[:,16],-900),'valid')
# Out:
# 0

# %%
# Q3
cor = np.zeros((3,1))
cor[0] = np.correlate(codes[:,8],np.roll(codes[:,8],1),'valid')
cor[1] = np.correlate(codes[:,8],np.roll(codes[:,8],0),'valid')
cor[2] = np.correlate(codes[:,8],np.roll(codes[:,8],-1),'valid')
plt.plot(np.array([-1,0,1]),cor)

# %%
# Q4
noisy = (np.array(codes[:,8])+ np.random.normal(0,4,1023))%2
# correlation(codes[:,8], noisy,200)
np.correlate(codes[:,8],np.roll(noisy,1),'valid')
# Out:
# array([-18.78219377])
