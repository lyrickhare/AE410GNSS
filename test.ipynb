# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.io as sio

# %%
# I got 32 PRN from this link

# %%
test = sio.loadmat("randomData/codes_L1CA.mat")

# %%
codes = np.array(test['codes_L1CA'])

# %%
def correlation(PRN1,PRN2,tau1=0,tau2=0):
    tau1 = tau1%1022
    tau2 = tau2%1022
    PRN1 = np.array(PRN1)
    PRN2 = np.array(PRN2)
    PRN1 = (np.array([PRN1,PRN1])).flat[tau1:1022+tau1]
    PRN2 = (np.concatenate([PRN2,PRN2])).flat[tau2:1022+tau2]
    return np.dot(PRN1,PRN2)

# %%
correlation(codes[:,0],codes[:,0])
# Out:
# 1022

# %%
PRN1=codes[:,0]

# %%
# idk smthng irnss https://www.researchgate.net/profile/Shylashree-Nn/publication/333893998_F11290476S419/links/5d0b4940299bf1f539d18e01/F11290476S419.pdf

# %%
plt.plot(np.random.normal(0, 1, 1000))

# %%
# Q1
correlation(codes[:,8],codes[:,8],0,200)
# Out:
# 0

# %%
# Q2
correlation(codes[:,8],codes[:,16],0,900)
# Out:
# 0

# %%
# Q3
cor = np.zeros(3)
cor[0] = correlation(codes[:,8],codes[:,8],0,-1)
cor[1] = correlation(codes[:,8],codes[:,8],0,0)
cor[2] = correlation(codes[:,8],codes[:,8],0,1)
plt.plot(np.array([-1,0,1]),cor)

# %%
# Q4
noisySignal = np.array(codes[:,8])+np.random.normal(0,4,1023)
correlation(codes[:,8],noisySignal,0,200)
# Out:
# 166.5363204728192
